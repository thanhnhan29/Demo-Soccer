# %%
# !wget -O tmp2.zip "https://ucbecd4874f12df6d297d31cbc96.dl.dropboxusercontent.com/zip_download_get/ClO3F6R5-mcuAfdGW0G5VOEfXk6NBH10Bkk_UTsLZTOT-kojyQGc2gIcyT866Jp9zjAM1T_uEDvY_OoaZxc8aGXmb8ub_rtZnyK76XQeoODBZg?_download_id=02252294300423007809962998936837421974669844787355151253561844997&_log_download_success=1&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2026-06-05 23:45:42--  https://ucbecd4874f12df6d297d31cbc96.dl.dropboxusercontent.com/zip_download_get/ClO3F6R5-mcuAfdGW0G5VOEfXk6NBH10Bkk_UTsLZTOT-kojyQGc2gIcyT866Jp9zjAM1T_uEDvY_OoaZxc8aGXmb8ub_rtZnyK76XQeoODBZg?_download_id=02252294300423007809962998936837421974669844787355151253561844997&_log_download_success=1&_notify_domain=www.dropbox.com&dl=1
# Resolving ucbecd4874f12df6d297d31cbc96.dl.dropboxusercontent.com (ucbecd4874f12df6d297d31cbc96.dl.dropboxusercontent.com)... 162.125.64.15, 2620:100:6020:15::a27d:400f
# Connecting to ucbecd4874f12df6d297d31cbc96.dl.dropboxusercontent.com (ucbecd4874f12df6d297d31cbc96.dl.dropboxusercontent.com)|162.125.64.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1293940545 (1.2G) [application/zip]
# Saving to: ‘tmp2.zip’
#
# tmp2.zip              0%[                    ]       0  --.-KB/s
# tmp2.zip            100%[===================>]   1.20G  18.5MB/s    in 63s
#
# ...

# %%
# !unzip tmp2.zip
# Out:
# Archive:  tmp2.zip
# ...
# mapname:  conversion of  failed
#  extracting: manchester-united-chelsea-fc-premier-league-2023-2024_1.mkv
#  extracting: manchester-united-chelsea-fc-premier-league-2023-2024_2.mkv

# %%
# !wget -O "2023-08-26_arsenal-fc-fulham-fc-premier-league-2023-2024.mkv" "https://uc56a96556fbbc5791fd2e1fd664.dl.dropboxusercontent.com/cd/0/get/DB2weTjg5N0WQzPknbZT_h1c2Ldzbcy0mH5S1QjRUdpjmMW8TuN21d6k7G1NqUcnJf3sZ6hQjtKZf0CYfd1Nz2WCJJElF2MIh0MmhRRgpMXaiYuQvQ03Z5Ea8CH6KH1ewpPcCs_wpsM9de7oX_sL1ZkyYN1H-lAf9bmOlJjw5KAa2gbMHECk_GOdrw9AZPsNcF8/file?_download_id=365954043210276912640014992737203193008520051799917467003082628535&_log_download_success=1&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2026-06-05 23:23:56--  https://ucdd3e48bc66d03e356d5afae2e8.dl.dropboxusercontent.com/cd/0/get/DB1NNS3ZSSxLJ8-2CYACX_9Te7qdSk4itYVI2-yw62KT3er08bm6ns-mxhrAe56crXdEnt0CrQIJ1PqLOyTrlWEmjB47YudCmUvbjvfiFfIh85aPi5XMF70Za8ogcxPZ9pTYeQcAEvKNcBtS_dtmLozDzOoWv1XTTE69K5nuE9qTe5uoeJDxxhhNhCYfdldUYOU/file?_download_id=88165882436373359639045830328076954662814026564826551833706434&_log_download_success=1&_notify_domain=www.dropbox.com&dl=1
# Resolving ucdd3e48bc66d03e356d5afae2e8.dl.dropboxusercontent.com (ucdd3e48bc66d03e356d5afae2e8.dl.dropboxusercontent.com)... 162.125.64.15, 2620:100:6020:15::a27d:400f
# Connecting to ucdd3e48bc66d03e356d5afae2e8.dl.dropboxusercontent.com (ucdd3e48bc66d03e356d5afae2e8.dl.dropboxusercontent.com)|162.125.64.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 592408874 (565M) [application/binary]
# Saving to: ‘2023-08-26_arsenal-fc-fulham-fc-premier-league-2023-2024.mkv’
#
# ...

# %%
path = "/raid/hvtham/SoccerNet/Demo-Soccer/manchester-united-chelsea-fc-premier-league-2023-2024_2"
mkv = path + ".mkv"
mp4 = path + ".mp4"

# %%
import subprocess

subprocess.run([
    "ffmpeg",
    "-i", mkv,
    "-c", "copy",
    mp4
], check=True)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (GCC)
# ...

# %%
with open("videos.txt", "w") as f:
    f.write("file '/raid/hvtham/SoccerNet/Demo-Soccer/manchester-united-chelsea-fc-premier-league-2023-2024_1.mp4'\n")
    f.write("file '/raid/hvtham/SoccerNet/Demo-Soccer/manchester-united-chelsea-fc-premier-league-2023-2024_2.mp4'\n")

# !ffmpeg -f concat -safe 0 -i videos.txt -c copy \
    "/raid/hvtham/SoccerNet/Demo-Soccer/manchester-united-chelsea-fc-premier-league-2023-2024_full.mp4"
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (GCC)
# ...
